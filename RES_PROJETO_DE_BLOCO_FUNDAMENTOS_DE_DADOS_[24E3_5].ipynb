# %% [markdown]
# <a href="https://colab.research.google.com/github/rssrafaela/PROJETO-DE-BLOCO-FUNDAMENTOS-DE-DADOS-24E3_5-/blob/main/RES_PROJETO_DE_BLOCO_FUNDAMENTOS_DE_DADOS_%5B24E3_5%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Projeto de Bloco: Fundamentos de Dados**
#
# Boas-vindas ao Projeto de Bloco: Fundamentos de Dados!
#
# Neste curso, iremos trabalhar no Projeto de Bloco, composto por 5 itens. Cada um desses itens será tratado em um dos Testes de Performance.
#
# Deste modo, estamos simulando a seguinte situação: Você faz parte de uma empresa de desenvolvimento e precisa desenvolver soluções em análises de dados. Cada um dos itens testarão as competências que você está desenvolvendo nas disciplinas regulares.
#
# Ao final do Projeto de Bloco, você irá entregar soluções que integram conhecimentos em Python e SQL, que são fundamentais para manipulação de dados.
#
# Ao final desta disciplina, você será capaz de demonstrar as seguintes competências:
# * Desenvolver programas simples em Python;
# * Recuperar informações de uma base de dados usando queries e agregações;
# * Manipular dados tabulares através de modelos SQL e estruturas de dados em Python;
# * Manipular dados provenientes de arquivos CSV e JSON através de programas que usem Python e SQL;
# * Realizar web scraping, manipulando os dados com SQL.

# %% [markdown]
# # **ETAPA 1 - Fundamentos de Programação para Manipulação de Dados**
#
# Na lição de hoje, aprenderemos a manipular variáveis, realizar operações matemáticas, trabalhar com strings, tomar decisões no código e muito mais!
#
# Competência(s) trabalhada(s) nessa etapa:
# * Desenvolver programas simples em Python.

# %% [markdown]
# Recomendação de Livros para leitura nessa ETAPA 1:

# %% [markdown]
# ![teste 13.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 14.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 15.png](data:image/png;base64,...)

# %% [markdown]
# # **AULA 1 - 23/07/2024**

# %% [markdown]
# Fizemos a leitura dos materiais - PDF's
# e testamos o primeiro código simples em Python

# %%
print('Olá, Mundo!')
# Out:
# Olá, Mundo!

# %% [markdown]
# # **AULA 2 - 30/07/2024**

# %% [markdown]
# **EXERCÍCIO 01:**

# %%
texto = 'Um monte palavras' # tipo string
print(texto) # imprime o valor da variável texto
quantidade = len(texto) # imprime o tamanho da variável texto
print(quantidade, 'caracteres','outro texto') #imprime o valor da variável quantidade e o texto
print(quantidade + 10) # imprime o valor da variável quantidade somando com 10

#-------------------------------------------------------------------------------

texto = "don't say that" # Coloca aspas dupla para não confundir com aspas simples dentro do texto
print(texto) # Imprime o valor da variável texto
# Out:
# Um monte palavras
# 17 caracteres outro texto
# 27
# don't say that

# %% [markdown]
# **EXERCÍCIO 02:**  Considere o seguinte trecho de código em Python:
#
# Qual dos seguintes tipos de erros pode ocorrer neste código?
#
# **A)** Erro de Sintaxe
# **B)** Erro de Lógica
# **C)** Erro de Tipos de Variáveis Incompatíveis
# **D)** Erro de Indentação
# **E)** Erro de Semântica
#
# **Resposta:** Erro de Tipos de Variáveis Incompatíveis / Se o usuário digitar uma letra ou qualquer outro valor que não possa ser convertido para um inteiro, isso gerará um erro.

# %%
num1 = int(input("Digite um número inteiro: "))
numero2 = int(input("Digite outro número inteiro: "))
somas = num1 + numero2
print("A soma dos números é: ", somas)
# Out:
# Digite um número inteiro: 5
# Digite outro número inteiro: 4
# A soma dos números é:  9

# %% [markdown]
# **EXERCÍCIO 03:** Exemplo simples de como a operação de concatenação de strings funciona em Python.

# %%
print('Olá ' + 'aí!')
# Out:
# Olá aí!

# %%
print('Olá ' + '123')
# Out:
# Olá 123

# %%
x = 'Olá ' + '123'
print(x)
# Out:
# Olá 123

# %%
print('-' * 30) # Coloca 30 hífens na tela
# Out:
# ------------------------------

# %%
print('hello'.upper()) # Converte tudo para maíusculo
# Out:
# HELLO

# %%
print('     abc    '.strip() + 'x') # Tira os espaços da String
# Out:
# abcx

# %%
print('     abc'.strip().upper()) # Concatenar Funções
# Out:
# ABC

# %%
print('abca'.strip('a')) # Retirar letra de uma string ou uma cadeia de caracteres
# Out:
# bc

# %%
print('abca'.count('a')) # Contar Caracteres
# Out:
# 2

# %%
print('ababa'.count('aba')) # Retornará 1, pois ele só pega a primeira sentença, atenção a sobreposição de palavras
# Out:
# 1

# %%
print('Esta é uma string com algumas palavras'.count(' ')+1) # Somando +1 para contar com a última palavra
# Out:
# 7

# %% [markdown]
# **EXERCÍCIO 04:** Operadores Aritméticos

# %%
print(8 + 10) # soma
# Out:
# 18

# %%
print(8 - 10) # subtração
# Out:
# -2

# %%
print(8 * 10) # multiplicação
# Out:
# 80

# %%
print(8 / 10) # divisão
# Out:
# 0.8

# %%
print( 8 // 10) # inteiro da divisão
# Out:
# 0

# %%
print( 8 % 3) # resto
# Out:
# 2

# %% [markdown]
# **EXERCÍCIO 05**: Calcular IMC

# %%
# Declaração de variáveis de ponto flutuante
altura = 1.75
peso = 68.5

# %%
# Opção 1

imc = peso / (altura * altura)

imc = round(imc,2) # Arrendondamento das casas decimais

imc2= int(imc)

print("IMC:", imc)
print(imc2)
# Out:
# IMC: 22.37
# 22

# %%
# Opção 2
imc = peso / (altura ** 2)

imc = round(imc,2) # Arrendondamento das casas decimais

imc2= int(imc)

print("IMC:", imc)
print(imc2)
# Out:
# IMC: 22.37
# 22

# %%
# Opção 3
imc = round(peso / (altura * altura) ,2)  # Arrendondamento das casas decimais junto com a devida operação

imc2= int(imc)

print("IMC:", imc)
print(imc2)
# Out:
# IMC: 22.37
# 22

# %% [markdown]
# **EXERCÍCIO 06:** Hirarquia Matemática

# %%
print(50 + 10 * 2) # Retornará 70
print((50 + 10) * 2)  # Retornará 120
# Out:
# 70
# 120

# %% [markdown]
# **EXERCÍCIO 07:** Tamanho que está sendo gasto na memória

# %%
print((5).bit_length()) # Retornou 3
print((100).bit_length()) # Retornou 7
print((99999).bit_length()) # Retornou 17
print((5.11).bit_length()) # Retorna um erro, pois só funciona com números inteiros
# Out:
# 3
# 7
# 17
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-e4a8e8122bd9> in <cell line: 4>()
#       2 print((100).bit_length()) # Retornou 7
#       3 print((99999).bit_length()) # Retornou 17
# ----> 4 print((5.11).bit_length()) # Retorna um erro, pois só funciona com números inteiros
#
# AttributeError: 'float' object has no attribute 'bit_length'

# %% [markdown]
# **EXERCÍCIO 08:** Retorna o tipo do parâmetro

# %%
print(type(14)) # Retornou <class 'int'>
print(type(9.5)) # Retornou <class 'float'>
print(type('hello')) # Retornou <class 'str'>
print(type(12 + 15)) # Retornou <class 'int'>
print(type(False)) # Retornou <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# **EXERCÍCIO 09:** Comparações

# %%
print('5 > 2',5 > 2) # Retornou True
print('9 > 10',9 > 10) # Retornou False
print('4 >= 4',4 >= 4) # Retornou True
print('4 >= 5',4 >= 5) # Retornou False
print('8 <= 6',8 <= 6) # Retornou False
print('5 == 5',5 == 5) # Retornou True
print('5 != 15',5 != 15) # Retornou True
print('Olá' == 'Olá','Olá' == 'Olá') # Retornou True
print("'bravo' < 'cavar'",'bravo' < 'cavar') # Retornou True
# Out:
# 5 > 2 True
# 9 > 10 False
# 4 >= 4 True
# 4 >= 5 False
# 8 <= 6 False
# 5 == 5 True
# 5 != 15 True
# True True
# 'bravo' < 'cavar' True

# %% [markdown]
# **EXERCÍCIO 10:** Considere o seguinte trecho de código em Python, que tem como objetivo calcular a média ponderada de três notas inseridas pelo usuário, considerando pesos diferentes:
#
# **Resposta:** Pode ocorrer um erro de divisão por zero.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
peso1 = int(input("Digite o peso da primeira nota: "))
peso2 = int(input("Digite o peso da segunda nota: "))
peso3 = int(input("Digite o peso da terceira nota: "))
media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso 3)
# Out:
#   File "<ipython-input-27-3e8fc286992e>", line 7
#     media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso 3)
#                                                                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # **ETAPA 2 - Programação e Documentação de Funções para Gestão de Dados.**
#
# Nesta lição, iremos aprender sobre programação com loops, modularização do código via funções e documentação com DocStrings.
#
# Competência(s) trabalhada(s) nessa etapa:
# * Desenvolver programas simples em Python.

# %% [markdown]
# Recomendação de Livros para leitura nessa ETAPA 2:

# %% [markdown]
# ![TESTE 1.png](data:image/png;base64,...)

# %% [markdown]
# ![TESTE 2.png](data:image/png;base64,...)

# %% [markdown]
# ![TESTE 3.png](data:image/png;base64,...)

# %% [markdown]
# # **AULA 3 - 06/08/2024**

# %% [markdown]
# **EXERCÍCIO 11:** Manipulação de Strings e Concatenação de Strings

# %%
inicio = 'Segunda-feira'
fim = 'Sexta-feira'
print(inicio)
print(fim)
print()
print('O período vai de: ', inicio + ' - ' + fim)
# Out:
# Segunda-feira
# Sexta-feira
#
# O período vai de:  Segunda-feira - Sexta-feira

# %% [markdown]
# **EXERCÍCIO 12:** Aritmética e Atualização de Variáveis

# %%
saldo = 250
saldo = saldo + 50
print(saldo)
print() # Pula uma linha
jan = 10
fev = 15.5
mar = 30.6
abr = 45.7
mai = 50.8
total = jan + fev + mar + abr + mai
media = (jan + fev + mar + abr + mai) / 5
print('Total:',total)
print('Média: ',media)
print()
print('Total arredondado: ',round(total,2))
print('Média arredondada: ',round(media,2))
# Out:
# 300
#
# Total: 152.60000000000002
# Média:  30.520000000000003
#
# Total arredondado:  152.6
# Média arredondada:  30.52

# %% [markdown]
# **EXERCÍCIO 13:** Declaração de Variáveis String

# %%
nome = input('Entre com o Nome: ')
sobrenome = input('Entre com o Sobrenome: ')
# Out:
# Entre com o Nome: Rafaela
# Entre com o Sobrenome: Souza

# %% [markdown]
# **EXERCÍCIO 14:** Concatenação de Strings

# %%
nome_completo = nome + ' ' + sobrenome
print("Nome completo: ", nome_completo)
# Out:
# Nome completo:  Rafaela Souza

# %% [markdown]
# **EXERCÍCIO 15:** Acesso a Caracteres Individuais

# %%
primeira_letra = nome[0]
print("Primeira letra do nome: ", primeira_letra)
# Out:
# Primeira letra do nome:  R

# %% [markdown]
# **EXERCÍCIO 16:** Calcular Volume

# %%
PI = 3.141592653589793
raio = input('Entre com o raio: ')
altura = input('Entre com a altura: ')
raio = int(raio)
altura = int(altura)
volume = round((PI * raio ** 2 * altura) / 3,2)
print(f'O volume é {volume}')
# Out:
# Entre com o raio: 3
# Entre com a altura: 4
# O volume é 37.7

# %% [markdown]
# **EXERCÍCIO 17:** Usando loop for para iterar até uma condição ser satisfeita

# %%
for contador in range(5):
  print(contador)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **EXERCÍCIO 18:** Iterando até uma condição ser satisfeita

# %%
contador = 0
while contador < 5:
  print(contador)
  contador +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **EXERCÍCIO 19:** Estruturas de Controle de Fluxo, especificamente Loops (Laços de Repetição) e Condicionais.

# %%
n = 3
while n > 0:
  if n == 5:
      n = -100
  print(n)
  n = n + 1
# Out:
# 3
# 4
# -100

# %% [markdown]
# **EXERCÍCIO 20:** Iterando com passos customizados usando range

# %%
for i in range(0, 10, 2): # começa com 0, vai até 10 (exclusive), com passo de 2
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# **EXERCÍCIO 21:** Interando sobre uma lista simples

# %%
numeros = [1, 2, 3, 4, 5]
for num in numeros:
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **EXERCÍCIO 22:** Interando sobre uma lista com índices / Interando com conchetes

# %%
frutas = ['maçã', 'banana', 'uva']
for index, fruta in enumerate(frutas):
  print(f"Index {index}: {frutas}")
# Out:
# Index 0: ['maçã', 'banana', 'uva']
# Index 1: ['maçã', 'banana', 'uva']
# Index 2: ['maçã', 'banana', 'uva']

# %% [markdown]
# **EXERCÍCIO 23:** Iterando sobre um dicionário / Interando com chaves

# %%
idades = {'João': 30, 'Alice': 25, 'Pedro': 35}

for nome, idade in idades.items():
  print(f"{nome} tem {idade} anos de idade.")
# Out:
# João tem 30 anos de idade.
# Alice tem 25 anos de idade.
# Pedro tem 35 anos de idade.

# %% [markdown]
# **EXERCÍCIO 24:** Iterando sobre uma string

# %%
mensagem = "Aula de Projeto de Bloco!"
for char in mensagem:
  print(char)
# Out:
# A
# u
# l
# a
#
# d
# e
#
# P
# r
# o
# j
# e
# t
# o
#
# d
# e
#
# B
# l
# o
# c
# o
# !

# %% [markdown]
# **EXERCÍCIO 25:** Iterando sobre múltiplas listas usando zip

# %%
nomes = ['Alice', 'Bob', 'Charlie']
idades = [25, 35, 30]
for nome, idade in zip(nomes, idades):
  print(f"{nome} tem {idade} anos de idade.")
# Out:
# Alice tem 25 anos de idade.
# Bob tem 35 anos de idade.
# Charlie tem 30 anos de idade.

# %% [markdown]
# **EXERCÍCIO 26:** Questão de concurso
#
# Ano: 2020 Banca: GUALIMP Órgão Prefeitura de Areal - Técnico de Informática
#
# Qual memória é conhecida como memória central, sendo uma memória de rápido acesso e que armazena os dados / informações (programas, objetos, dados de entrada e saída, dados do sistema operacional)?
#
# **A)** Memória de Leitura
# **B)** Memória Cache
# **C)** Memória Principal
# **D)** Memória Externa
#
# **Resposta:** Memória Principal

# %% [markdown]
# **EXERCÍCIO 27:** Acesso e Exibição de Informações do Processador com Bibliotecas Externas

# %%
import cpuinfo

info = cpuinfo.get_cpu_info()
for i in info:
  print(i, ":", info[i])
# Out:
# python_version : 3.10.12.final.0 (64 bit)
# cpuinfo_version : [9, 0, 0]
# cpuinfo_version_string : 9.0.0
# arch : X86_64
# bits : 64
# count : 2
# arch_string_raw : x86_64
# vendor_id_raw : GenuineIntel
# brand_raw : Intel(R) Xeon(R) CPU @ 2.20GHz
# hz_advertised_friendly : 2.2000 GHz
# hz_actual_friendly : 2.2000 GHz
# hz_advertised : [2200000000, 0]
# hz_actual : [2199998000, 0]
# model : 79
# family : 6
# ...

# %% [markdown]
# # **AULA 4 - 13/08/2024**

# %% [markdown]
# **EXERCÍCIO 28:** Estrutura de repetição / identação

# %%
palavra_secreta = 'python'
for chat in palavra_secreta:
    print('Letra: ', chat)

print('fim')
# Out:
# Letra:  p
# Letra:  y
# Letra:  t
# Letra:  h
# Letra:  o
# Letra:  n
# fim

# %% [markdown]
# **EXERCÍCIO 29:** Estrutura de repetição com palavra

# %%
palavra_secreta = 'python'
contador = 0
for chat in palavra_secreta:
  contador = contador + 1
  print('Letra ' + str(contador) + ': ' + chat)

print(palavra_secreta, 'tem', len(palavra_secreta), 'caracteres')
# Out:
# Letra 1: p
# Letra 2: y
# Letra 3: t
# Letra 4: h
# Letra 5: o
# Letra 6: n
# python tem 6 caracteres

# %% [markdown]
# **EXERCÍCIO 30:** Combinação de letras e dígitos

# %%
letras = 'ABC'
digitos = '123'

for letra in letras:
  for digito in digitos:
    print(letra + digito)
# Out:
# A1
# A2
# A3
# B1
# B2
# B3
# C1
# C2
# C3

# %% [markdown]
# **EXERCÍCIO 31:** Manipulação de Strings e Contagem de Caracteres

# %%
s = 'garagem'
total = 0
for char in s:
  total = total + s.count(char)
print(total)
# Out:
# 11

# %%
print('aula'.isupper())

print('A'.upper())
# Out:
# False
# A

# %% [markdown]
# **EXERCÍCIO 32:** Criar uma lista

# %%
lista = [1, 2, 3, 4, 5]

# %%
# Acessar elementos da lista pelo índice
print("Primeiro elemento:", lista[0])
print("Último elemento:", lista[-1])
# Out:
# Primeiro elemento: 1
# Último elemento: 5

# %%
# Adicionar elementos à lista
lista = []  # Certifique-se de que a lista foi definida
lista.append(6)
lista.insert(0, 0)  # Adiciona 0 no início da lista
print("Lista após adicionar elementos:", lista)
# Out:
# Lista após adicionar elementos: [0, 6]

# %%
# Remover elementos da lista
lista = [0, 6]  # Exemplo de lista inicial

lista.pop()  # Remove o último elemento (6)
# Verifica se o número 3 está na lista antes de tentar removê-lo
if 3 in lista:
    lista.remove(3)  # Remove o elemento 3, se existir

print("Lista após remover elementos:", lista)
# Out:
# Lista após remover elementos: [0]

# %%
# Verificar se um elemento está na lista

if 2 in lista:
  print("2 está na lista")
else:
  print("2 não está na lista")
# Out:
# 2 não está na lista

# %%
# Ordenar a lista
lista.sort()
print("Lista ordenada: ", lista)
# Out:
# Lista ordenada:  [0]

# %%
# Inverter a lista
lista.reverse()
print("Lista invertida: ", lista)
# Out:
# Lista invertida:  [0]

# %%
# Copiar a lista
copia_lista = lista.copy()
print(copia_lista)
lista2 = lista
print('lista2', lista2)
# Out:
# [0]
# lista2 [0]

# %%
# Limpar a lista
lista.clear()
print("Lista após limoar: ", lista)
# Out:
# Lista após limoar:  []

# %% [markdown]
# **EXERCÍCIO 33:** Definição e Chamada de Funções em Python

# %%
def diga_alo():
    print("Alô, Infnet!")

diga_alo()
# Out:
# Alô, Infnet!

# %%
def saudar(nome):
    print(f"Olá, {nome}!")

pessoa = input('Digite seu nome: ')
saudar(pessoa)
# Out:
# Digite seu nome: Rafaela
# Olá, Rafaela!

# %%
def multiplicacao(x):
  z = x * x
  return z

valor = int(input('Entre com o valor: '))
resultado = multiplicacao(valor)
print('O número',valor, 'multiplicado a ele mesmo é', resultado)
# Out:
# Entre com o valor: 4
# O número 4 multiplicado a ele mesmo é 16

# %%
def soma_de_valores(*argumentos):
  total = 0
  for valor in argumentos:
      total += valor
  return total

resultado = soma_de_valores(1, 2, 3, 4, 5)
print(resultado)
# Out:
# 15

# %%
def saudar(nome, saudando="Olá"):
  print(f"{saudando}, {nome}!")

saudar("João")
saudar("Maria", saudando="Como vai")
# Out:
# Olá, João!
# Como vai, Maria!

# %% [markdown]
# # **ETAPA 3 - Aplicação de Queries e Operadores Lógicos em Base de Dados**
#
# Na lição de hoje, iremos aprender sobre como recuperar dados de uma base usando queries e operadores lógicos para filtrar informações.
#
# Competência(s) trabalhada(s) nessa etapa:
# * Recuperar informações de uma base de dados usando queries e agregações.

# %% [markdown]
# Recomendação de livros para leitura nessa ETAPA 3.

# %% [markdown]
# ![TESTE 4.png](data:image/png;base64,...)

# %% [markdown]
# ![TESTE 5.png](data:image/png;base64,...)

# %% [markdown]
# # **AULA 5 - 20/08/2024**

# %% [markdown]
# **O que são Bancos de Dados?**
#
# Um banco de dados é como um grande armário digital onde você guarda informações de forma organizada. Em vez de ter papéis espalhados, você usa um banco de dados para armazenar e acessar suas informações de maneira rápida e organizada.
#
# **O que é um Sistema Gerenciador de Banco de Dados (SGBD)?**
#
# Um SGBD é um programa de computador que ajuda você a criar e gerenciar esses "armários" de dados. Ele facilita a adição, a atualização e a busca de informações dentro do banco de dados.
#
# **Como se Conecta a um Banco de Dados?**
#
# Para conectar a um banco de dados, você usa um programa (cliente) que se comunica com o banco através de um "driver" que traduz suas solicitações. O banco de dados em si está em um servidor, que é onde as informações estão armazenadas.
#
# **Vantagens de Usar um Banco de Dados**
#
# Centralização: Guarda tudo em um só lugar.
#
# Segurança: Controla quem pode ver e modificar as informações.
#
# Precisão: Garante que as informações sejam corretas.
#
# Rapidez: Permite encontrar e usar informações rapidamente.
#
# **Dados vs. Informação**
#
# Dados: São pedaços brutos de informações, como números ou palavras, que sozinhos não têm muito sentido.
#
# Informação: É quando os dados são organizados e interpretados para ter significado. Por exemplo, uma lista de números pode ser apenas dados, mas se você organizar esses números em uma tabela de vendas, eles se tornam informações úteis.
#
# **Metadados**
#
# Metadados são "dados sobre dados". Eles descrevem e explicam os dados que você tem, ajudando a entender o que eles significam e como estão organizados.
#
# **Exemplos de Bancos de Dados**
#
# MySQL: Usado para websites e aplicações.
#
# PostgreSQL: Outro banco de dados popular, conhecido por ser poderoso.
#
# MongoDB: Guarda dados de forma mais flexível, ideal para certos tipos de aplicativos.
#
# Oracle: Um banco de dados robusto usado por grandes empresas.
#
# **Níveis de Abstração**
#
# Visão do Usuário: Como você vê e usa os dados, como em um aplicativo ou site.
#
# Nível Conceitual: A estrutura geral dos dados, sem se preocupar com como eles estão armazenados.
#
# Nível Físico: Como os dados são realmente armazenados no disco rígido do computador.
#
# **Diagrama Entidade-Relacionamento**
#
# Imagine um diagrama que mostra como diferentes partes de uma base de dados estão conectadas. Por exemplo, pode mostrar que "Clientes" fazem "Pedidos" e como essas duas partes estão relacionadas.
#
# **Exemplo de Tabelas**
#
# Tabela Cliente: Guarda informações como nome e telefone dos clientes.
#
# Tabela Pedido: Guarda detalhes sobre os pedidos, como a data e a quem pertence.
#
# **Exemplo de Relacionamento**
#
# Se você tem uma tabela de "Clientes" e uma tabela de "Pedidos", cada pedido na tabela de "Pedidos" está relacionado a um cliente na tabela de "Clientes". Isso ajuda a saber qual cliente fez qual pedido.

# %% [markdown]
# **Alguns BD para instalação:**
#
# SQLITE: https://sqlitestudio.pl/
#
# POSTGRESQL: https://www.postgresql.org/download/
#
# REPLIT: Selecionar SQLite

# %%
SELECT 'Hello World!';

# %%
CREATE TABLE people(
	name VARCHAR(50),
	age INT
);

# %%
CREATE TABLE pessoas (nome VARCHAR(50),idade INT);

# %% [markdown]
# O código cria uma tabela chamada people com duas colunas: name para armazenar nomes de até 50 caracteres e age para armazenar idades como números inteiros. Em seguida, ele insere três registros na tabela: Maria com 30 anos, Obama com 60 anos e Pedro com 40 anos.
#
# Depois, o código tenta executar algumas consultas:
#
# **Seleciona todos os registros da tabela:**
#
# - SELECT * FROM people;
#
# **Obtém a idade de Obama:**
#
# - SELECT age FROM people WHERE name = 'Obama';

# %%
-- Faz a criação da tabela people
CREATE TABLE people (
	name VARCHAR(50),
	age INT
);

--- Faz a inserção de dados na tabela people
INSERT INTO people (name, age)
VALUES ('Maria', 30);

INSERT INTO people (name, age)
VALUES ('Obama', 60);

INSERT INTO people (name, age)
VALUES ('Pedro', 40)

select('');
--Trazer todo mundo
select * from people
select('');

--Idade do Obama
select AGE from people
WHERE name = 'Obama';

select('');

# %% [markdown]
# # **AULA 6 - 27/08/2024**

# %% [markdown]
# Alteramos a IDE Replit para Online SQL Editor:
#
# https://www.programiz.com/sql/online-compiler/

# %% [markdown]
# **EXERCÍCIO 34:**

# %% [markdown]
# ![EXERCICIO 34 - SQL.PNG](data:image/png;base64,...)

# %% [markdown]
# **EXERCÍCIO 35:**

# %% [markdown]
# **CREATE TABLE Pessoas:** Cria uma nova tabela chamada Pessoas.
#
# **id INT PRIMARY KEY:** Define uma coluna chamada id que armazenará números inteiros (INT) e que será a chave primária da tabela. Isso significa que cada id será único e identificará de forma exclusiva cada pessoa na tabela.
#
# **nome VARCHAR(255) NOT NULL:** Define uma coluna chamada nome que armazenará texto (strings) com até 255 caracteres (VARCHAR(255)). O NOT NULL significa que essa coluna não pode ficar vazia; cada pessoa deve ter um nome.
#
# **idade INT NOT NULL:** Define uma coluna chamada idade que armazenará números inteiros (INT) e também não pode ser vazia (NOT NULL). Cada pessoa deve ter uma idade.
#
# **INSERT INTO Pessoas (id, nome, idade) VALUES (...):** Adiciona várias linhas de dados à tabela Pessoas. Cada linha contém um id, um nome e uma idade. Por exemplo, a primeira linha adiciona uma pessoa com id 1, nome "Joao" e idade 20.
#
# **SELECT * FROM Pessoas:** Recupera e mostra todos os dados armazenados na tabela Pessoas. O * significa que você quer ver todas as colunas.
#
# **Resumindo:** o código cria uma tabela chamada Pessoas com três colunas (id, nome e idade), insere algumas pessoas nessa tabela e depois mostra todos os dados dessa tabela.

# %%
CREATE TABLE Pessoas (
 id INT PRIMARY KEY,
 nome VARCHAR(255) NOT NULL,
 idade INT NOT NULL
 );

INSERT INTO Pessoas (id, nome, idade) VALUES
(1, 'Joao', 20),
(2, 'Maria', 22),
(3, 'Pedro', 21),
(4, 'Ana', 23),
(5, 'Carlos', 20);

SELECT * FROM Pessoas;

# %% [markdown]
# **TODOS OS SELECT APRESENTADOS NESSA AULA:**

# %%
--CREATE TABLE Pessoas (
--    id INT PRIMARY KEY,
--    nome VARCHAR(255) NOT NULL,
--    idade INT NOT NULL
--);

--INSERT INTO Pessoas (id, nome, idade) VALUES
--(1, 'Joao', 20),
--(2, 'Maria', 22),
--(3, 'Pedro', 21),
--(4, 'Ana', 23),
--(5, 'Carlos', 20);

--Todos
--SELECT * FROM Pessoas;

--Pessoas com idade maior que 21
--SELECT * FROM Pessoas WHERE idade > 21;

--Ordenando Pessoas por idade em ordem decrescente
--SELECT * FROM Pessoas ORDER BY NOME DESC;

--Contando o número de Pessoas com idade maior que 20
--SELECT COUNT(*) FROM Pessoas WHERE idade > 20;

--Selecionando a pessoa mais nova:
--SELECT * FROM Pessoas WHERE idade = (SELECT MIN(idade) FROM Pessoas);

--Selecionando Pessoas com idade entre 20 e 22 anos
--SELECT * FROM Pessoas WHERE idade BETWEEN 20 AND 22;

--Selecionando o nome e a idade dos Pessoas com idade maior que 20
--SELECT nome, idade FROM Pessoas WHERE idade > 20;

--Selecionando o nome do aluno mais velho
--SELECT nome FROM Pessoas WHERE idade = (SELECT MAX(idade) FROM Pessoas);

--Selecionar as idades que existem na base
--SELECT idade FROM Pessoas GROUP BY idade;

--Selecionando as três Pessoas mais velhas
--SELECT * FROM Pessoas ORDER BY idade DESC LIMIT 3;

--Calculando a média de idade dos Pessoas:
--SELECT AVG(idade) FROM Pessoas;

--Selecionando Pessoas com nome que começa com 'J'
--SELECT * FROM Pessoas WHERE nome LIKE 'j%';

--Selecionando Pessoas com idade ímpar:
--SELECT * FROM Pessoas WHERE idade % 2 <> 0;

--Selecionando o nome do aluno mais novo com idade ímpar:
--SELECT nome FROM Pessoas WHERE idade % 2 <> 0 ORDER BY idade LIMIT 1;

--Selecionando Pessoas com idade múltipla de 3:
--SELECT * FROM Pessoas WHERE idade % 3 = 0;

--Selecionando Pessoas com nomes duplicados:
--INSERT INTO Pessoas (id, nome, idade) VALUES
--(6, 'barbara', 20),
--(7, 'joana', 22),
--(8, 'Pedro', 21),
--(9, 'Ana', 23),
--(10, 'Ana', 20);
--SELECT * FROM Pessoas;
SELECT nome, COUNT(*) FROM Pessoas GROUP BY nome HAVING COUNT(*) > 1;

# %% [markdown]
# **Documentário sobre Chave Estrangeira x Chave Primária – Qual é a Diferença?**
#
# https://www.linkedin.com/pulse/chave-estrangeira-x-prim%C3%A1ria-qual-%C3%A9-diferen%C3%A7a-asakura/?originalSubdomain=pt

# %% [markdown]
# Este artigo oferecerá a diferença entre uma chave primária e uma chave estrangeira. E abordará o porquê essas duas chaves são importantes quando se trata da manutenção de uma estrutura de banco de dados relacional.
#
# Todos os exemplos desta lição são baseados no erwin Data Modeler, numa visão de modelo físico e no banco de dados Microsoft SQL Server.
#
# **Chaves Primárias versus Chaves Estrangeiras**
#
# Antes de nos aprofundarmos na diferença, vamos primeiro explorar as características das chaves primárias e estrangeiras. Vamos começar aprendendo sobre chaves primárias.
#
# **Chaves Primárias (PK)**
#
# Não foi fornecido texto alternativo para esta imagem
# Para que uma tabela se qualifique como uma tabela relacional, ela deve ter uma chave primária.
#
# A **chave primária** consiste em uma ou mais colunas cujos dados contidos são usados para identificar exclusivamente cada linha na tabela. Você pode pensar neles como um endereço. Se as linhas de uma tabela fossem caixas de correio, a chave primária seria a listagem de endereços de rua.
#
# Para ser uma chave primária, várias condições devem ser verdadeiras:
#
# - As colunas que definem a chave primária são exclusivas.
#
# - Cada coluna pode conter valores duplicados; no entanto, a combinação de valores de coluna é exclusiva.
#
# - Nenhum valor nas colunas de chave primária é NULL. Eu também estenderia isso para incluir valores “em branco”.
#
# - Ao definir uma tabela, você especifica a chave primária. Uma tabela possui apenas uma chave primária e sua definição é obrigatória.
#
# - As chaves primárias são armazenadas em um índice.
#
# - O índice mantém o requisito de exclusividade da chave primária. Também torna mais fácil para os valores de chave estrangeira se referirem aos valores de chave primária correspondentes, como aprenderemos na seção a seguir.
#
# Quer saber mais sobre design de banco de dados? Um dos primeiros obstáculos que você vai querer superar é a Normalização do Banco de Dados. Falaremos um dia sobre este assunto.
#
# **Chaves Estrangeiras (FK)**
#
# Uma chave estrangeira é um conjunto de uma ou mais colunas em uma tabela que se refere à chave primária em outra tabela. Não há nenhum código especial, configurações ou definições de tabela que você precise colocar para “designar” oficialmente uma chave estrangeira.
#
# No diagrama abaixo, observe a tabela **CABECALHO_PEDIDO_VENDA**. A coluna **CABECALHO_PEDIDO_VENDA.Codigo_Taxa_Cambio** é uma chave estrangeira, pois está relacionada ao **TAXA_CAMBIO**. **Codigo_Taxa_Cambio**. Esta coluna **TAXA_CAMBIO**. **Codigo_Taxa_Cambio** é a chave primária da tabela **TAXA_CAMBIO**.

# %% [markdown]
# ![CHAVE ESTRANGEIRA.PNG](data:image/png;base64,...)

# %% [markdown]
# **Chaves Trabalhando Juntas**
#
# Observe o diagrama a seguir. Qual coluna é a chave estrangeira?

# %% [markdown]
# ![IMAGEM 2.PNG](data:image/png;base64,...)

# %% [markdown]
# Se você disse que era TELEFONE_PESSOA.Codigo_Entidade_Negocio, então você está correto. A razão pela qual é uma chave estrangeira é que ela está se referindo a uma chave primária, PESSOA.Codigo_Entidade_Negocio, na outra tabela.
#
# Coincidentemente, TELEFONE_PESSOA. Codigo_Entidade_Negocio não é apenas uma chave estrangeira, mas também faz parte da chave primária de TELEFONE_PESSOA. A chave primária da tabela TELEFONE_PESSOA é a combinação de Codigo_Entidade_Negocio, Numero_Telefone e Codigo_Tipo_Telefone.

# %% [markdown]
# ![IMAGEM 3.PNG](data:image/png;base64,...)

# %% [markdown]
# **Use o Model Explorer para Encontrar Chaves de Banco de Dados**
#
# Ao usar o erwin Data Modeler, você encontrará todos os tipos de informações úteis no Model Explorer, assim como nos diagramas. Você não precisa navagar fundo para encontrar as chaves primárias, pois, no diagrama todas as colunas acima da linha horizontal, compõe a chave primária (PK). Quando você mostra as colunas de uma tabela, mas clicando na pasta Columns, as colunas de chave primária têm chaves douradas ao lado delas.
#
# Além disso, se qualquer uma das chaves estrangeiras for definida em restrições de chave estrangeira, o que aprenderemos na seção a seguir, essas colunas terão (FK) depois delas.

# %% [markdown]
# ![IMAGEM 4.PNG](data:image/png;base64,...)

# %% [markdown]
# **Restrições de Chave Estrangeira**
#
# Alguns sistemas de gerenciamento de banco de dados, como o SQL Server, permitem configurar restrições de chave estrangeira. Estes ajudam a reforçar a integridade referencial. Em sua forma mais simples, uma restrição de chave estrangeira impede que você insira valores que não são encontrados na chave primária da tabela relacionada.
#
# Usando o primeiro diagrama como nosso exemplo, você não pode inserir CABECALHO_PEDIDO_VENDA.Codigo_Taxa_Cambio se ainda não existir na tabela TAXA_CAMBIO.
#
# Essas restrições entram em vigor de várias maneiras:
# 1.
# Eles impedem que você altere o valor da chave estrangeira para um que não exista como um valor na chave primária da tabela relacionada.
# 2. Eles impedem que você exclua uma linha da tabela de chave primária. Isso impede que você crie registros órfãos. Registros órfãos são descritos como “registros filhos sem pais”.
# 3. Eles impedem você de adicionar um valor de chave estrangeira que não existe na chave primária.
#
# Em resumo, as restrições impõem o relacionamento entre as tabelas de chave primária e estrangeira.

# %% [markdown]
# ![IMAGEM 5.PNG](data:image/png;base64,...)

# %% [markdown]
# **Resposta à pergunta:**
#
# Anteriormente, pedimos que você identificasse a outra chave estrangeira na tabela TELEFONE_PESSOA. A resposta correta é Codigo_Tipo_Telefone.

# %% [markdown]
# **Conclusão**
#
# Uma chave primária é necessária para definir uma tabela de banco de dados relacional. Uma chave estrangeira é uma ou mais colunas de outra tabela que faz referência à chave primária de uma tabela. Em alguns SGBDs, defina restrições de chave estrangeira para proteger esse relacionamento.

# %% [markdown]
# **QUESTÃO DE CONCURSO - ANO: 2016 BANCA: FCM ÓRGÃO: IFF-RS PROVA - TÉCNICO DE TECNOLOGIA DA INFORMAÇÃO. MARQUE A OPÇÃO CORRETA:**
#
# 1. Não é possível a criação de uma tabela sem chave primária.
#
# 2. A chave primária de uma tabela deve ser sempre única e não nula.
#
# 3. As chaves, primária e estrangeira, de uma tabela, devem ser do tipo numérico.
#
# 4. A cláusula UNIQUE, aplicada a chave estrangeira, é responsável pela integridade referencial do relacionamento.
#
# 5. As chaves primárias podem ser compostas por um ou mais atributos, porém as chaves estrangeiras devem ser compostas somente por um atributo.
#
# **RESPOSTA:** ALTERNATIVA CORRETA É A NÚMERO DOIS.
#
# **2. A chave primária de uma tabela deve ser sempre única e não nula.**

# %% [markdown]
# # **AULA 7 - 03/09/2024**

# %% [markdown]
# # **ETAPA 4 - Recuperação e Agregação de Dados**
#
# Nesta lição, aprenderemos como recuperar e organizar dados com ORDER BY e realizar agregações com GROUP BY.
#
# Competência(s) trabalhada(s) nessa etapa:
#
# - Recuperar informações de uma base de dados usando queries e agregações.

# %% [markdown]
# ![TESTE 6.png](data:image/png;base64,...)

# %% [markdown]
# ![TESTE 7.png](data:image/png;base64,...)

# %% [markdown]
# Fizemos e leitura do Teste de Performance 2 (TP2)

# %% [markdown]
# **Exemplo de ferramenta para fazer diagramas:**
#
# https://app.diagrams.net/

# %%
-- Primeiro, exclua tabelas existentes se elas existirem
DROP TABLE IF EXISTS Alunos;
DROP TABLE IF EXISTS Disciplinas;
DROP TABLE IF EXISTS Turmas;

-- Tabela Turmas
CREATE TABLE Turmas (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT NOT NULL,
    ano TEXT NOT NULL
);

INSERT INTO Turmas (nome, ano) VALUES
('Turma A', '2024'),
('Turma B', '2024'),
('Turma C', '2024'),
('Turma D', '2024'),
('Turma E', '2024');

-- Tabela Alunos
CREATE TABLE Alunos (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT NOT NULL,
    idade INTEGER NOT NULL,
    id_turma INTEGER,
    FOREIGN KEY(id_turma) REFERENCES Turmas(id)
);

INSERT INTO Alunos (nome, idade, id_turma) VALUES
('João', 20, 1),
('Maria', 21, 1),
('Pedro', 19, 2),
('Ana', 22, 2),
('Lucas', 20, 3),
('Mariana', 21, 3),
('Rafael', 19, 4),
('Carla', 22, 4),
('Felipe', 20, 5),
('Julia', 21, 5);

-- Tabela Disciplinas
CREATE TABLE Disciplinas (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT NOT NULL,
    codigo TEXT NOT NULL,
    id_turma INTEGER,
    FOREIGN KEY(id_turma) REFERENCES Turmas(id)
);

INSERT INTO Disciplinas (nome, codigo, id_turma) VALUES
('Matemática', 'MAT101', 1),
('Português', 'POR101', 1),
('História', 'HIS101', 1),
('História', 'HIS101', 2),
('Geografia', 'GEO101', 2),
('Física', 'FIS101', 3),
('Química', 'QUI101', 3),
('Biologia', 'BIO101', 4),
('Inglês', 'ING101', 4),
('Educação Física', 'EDF101', 5),
('Artes', 'ART101', 5);

# %% [markdown]
# **Outra IDE online recomendada pelo professor:**
#
# https://sqliteonline.com/

# %%
SELECT * FROM Alunos;

# %% [markdown]
# ![anexo 1.PNG](data:image/png;base64,...)

# %% [markdown]
# **--Selecionar todos os alunos de uma turma específica (por exemplo, Turma A):**
#
# SELECT Alunos.* FROM Alunos
#
# JOIN Turmas ON Alunos.id_turma = Turmas.id WHERE Turmas.nome = 'Turma A';

# %% [markdown]
# ![anexo 2.PNG](data:image/png;base64,...)

# %% [markdown]
# **-- Selecionar todas as disciplicas de um aluno específico (por exemplo, João):**
#
# SELECT Disciplinas.nome FROM Alunos
#
# JOIN Turmas ON Alunos.id_turma = Turmas.id
#
# JOIN Disciplinas ON Disciplinas.id_turma = Turmas.id WHERE Alunos.nome = 'João';

# %% [markdown]
# ![anexo 3.PNG](data:image/png;base64,...)

# %% [markdown]
# **-- Selecionar todos os alunos que cursam uma disciplina específica (por exemplo, Matemática):**
#
# SELECT Alunos.nome FROM Alunos
#
# JOIN Turmas ON Alunos.id_turma = Turmas.id
#
# JOIN Disciplinas ON Disciplinas.id_turma = Turmas.id WHERE Disciplinas.nome = 'Matemática';

# %% [markdown]
# ![anexo 4.PNG](data:image/png;base64,...)

# %% [markdown]
# # **ETAPA 5 - Aprimorando Querys SQL: Uso Avançado de Agregações, Filtragens e Restrições**
#
# Na lição de hoje, iremos aprender sobre filtragens e agregações em SQL, impondo integridade de dados com restrições UNIQUE e NOT NULL.
#
# Competência(s) trabalhada(s) nessa etapa:
#
# - Manipular dados tabulares através de modelos SQL e estruturas de dados em Python.

# %% [markdown]
# ![TESTE 8.png](data:image/png;base64,...)

# %% [markdown]
# ![TESTE 9.png](data:image/png;base64,...)

# %% [markdown]
# # **AULA 8 - 10/09/2024**

# %% [markdown]
# **-- Selecionar todas as disciplinas de uma turma específica (por exemplo, Turma B):**
#
# SELECT Disciplinas.nome FROM Turmas
#
# JOIN Disciplinas ON Disciplinas.id_turma = Turmas.id WHERE Turmas.nome = 'Turma B';

# %% [markdown]
# ![teste 1.png](data:image/png;base64,...)

# %% [markdown]
# **-- Selecionar todos os alunos que cursam disciplinas em comum com um aluno específico (por exemplo, João):**
#
# SELECT DISTINCT Alunos.nome FROM Alunos
#
# JOIN Turmas ON Alunos.id_turma = Turmas.id
#
# JOIN Disciplinas ON Disciplinas.id_turma = Turmas.id
#
# WHERE Alunos.nome <> 'João'
#
# AND Alunos.id_turma IN (
#
#   SELECT Alunos.id_turma FROM Alunos
#
#   JOIN Turmas ON Alunos.id_turma = Turmas.id
#
#   JOIN Disciplinas ON Disciplinas.id_turma = Turmas.id
#
#   WHERE Alunos.nome = 'João');

# %% [markdown]
# ![teste 2.png](data:image/png;base64,...)

# %% [markdown]
# **-- Selecionar todas as disciplinas de uma turma que não estão sendo cursadas por nenhum aluno:**
#
# SELECT Disciplinas.nome FROM Disciplinas
#
# LEFT JOIN (
#
#   SELECT DISTINCT id_turma FROM Alunos
#
# )
#
# AS AlunosTurmas ON Disciplinas.id_turma = AlunosTurmas.id_turma
#
# WHERE AlunosTurmas.id_turma IS NULL;

# %% [markdown]
# ![teste 3.png](data:image/png;base64,...)

# %% [markdown]
# Código abaixo disponibilizado no Dontpad em aula: https://dontpad.com/dolavale-2024-09-10-3

# %% [markdown]
# CREATE TABLE Categorias (
#
#     id_categoria INTEGER PRIMARY KEY,
#     nome_categoria TEXT
# );
#
# CREATE TABLE Produtos (
#
#     id_produto INTEGER PRIMARY KEY,
#     nome_produto TEXT,
#     preco_unitario REAL,
#     descricao TEXT,
#     id_categoria INTEGER,
#     FOREIGN KEY (id_categoria) REFERENCES Categorias(id_categoria)
# );
#
# CREATE TABLE Clientes (
#
#     id_cliente INTEGER PRIMARY KEY,
#     nome_cliente TEXT,
#     email_cliente TEXT,
#     endereco TEXT
# );
#
# CREATE TABLE Pedidos (
#
#     id_pedido INTEGER PRIMARY KEY,
#     id_cliente INTEGER,
#     data_pedido DATE,
#     status_pedido TEXT,
#     FOREIGN KEY (id_cliente) REFERENCES Clientes(id_cliente)
# );
#
# CREATE TABLE ItensPedido (
#
#     id_item INTEGER PRIMARY KEY,
#     id_pedido INTEGER,
#     id_produto INTEGER,
#     quantidade INTEGER,
#     FOREIGN KEY (id_pedido) REFERENCES Pedidos(id_pedido),
#     FOREIGN KEY (id_produto) REFERENCES Produtos(id_produto)
# );
#
# **-- Inserindo registros na tabela Categorias**
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Eletrônicos');
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Moda');
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Casa e Jardim');
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Esportes e Lazer');
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Beleza e Saúde');
#
# **-- Inserindo registros na tabela Produtos**
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 1', 10.00, 'Descrição 1', 1);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 2', 20.00, 'Descrição 2', 2);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 3', 30.00, 'Descrição 3', 3);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 4', 40.00, 'Descrição 4', 4);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 5', 50.00, 'Descrição 5', 5);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 6', 60.00, 'Descrição 6', 1);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 7', 70.00, 'Descrição 7', 2);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 8', 80.00, 'Descrição 8', 3);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 9', 90.00, 'Descrição 9', 4);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 10', 100.00, 'Descrição 10', 5);
#
#
# **-- Inserindo registros na tabela Clientes**
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 1', 'cliente1@example.com', 'Endereço 1');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 2', 'cliente2@example.com', 'Endereço 2');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 3', 'cliente3@example.com', 'Endereço 3');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 4', 'cliente4@example.com', 'Endereço 4');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 5', 'cliente5@example.com', 'Endereço 5');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 6', 'cliente6@example.com', 'Endereço 6');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 7', 'cliente7@example.com', 'Endereço 7');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 8', 'cliente8@example.com', 'Endereço 8');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 9', 'cliente9@example.com', 'Endereço 9');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 10', 'cliente10@example.com', 'Endereço 10');
#
# **-- Inserindo registros na tabela Pedidos**
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (1, 1, '2024-03-19', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (2, 2, '2024-03-18', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (3, 3, '2024-03-17', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (4, 4, '2024-03-16', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (5, 5, '2024-03-15', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (6, 6, '2024-03-14', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (7, 7, '2024-03-13', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (8, 8, '2024-03-12', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (9, 9, '2024-03-11', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (10, 10, '2024-03-10', 'Concluído');
#
# **-- Inserindo registros na tabela ItensPedido**
#
#
# **-- Pedido 1**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 5, 1);
#
#
# **-- Pedido 2**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 6, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 7, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 8, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 9, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 10, 3);
#
# **-- Pedido 3**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 5, 1);
#
# **-- Pedido 4**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 6, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 7, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 8, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 9, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 10, 3);
#
# **-- Pedido 5**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 5, 1);
#
#
# **-- Atualizando clientes**
#
# UPDATE Clientes
#
# SET nome_cliente  = 'João Silva',
#
#     email_cliente = 'joao.silva@example.com',
#     endereco      = 'Rua A, 123'
#
# WHERE id_cliente = 1;
#
# UPDATE Clientes SET nome_cliente = 'Maria Santos', email_cliente = 'maria.santos@example.com', endereco = 'Av. B, 456' WHERE id_cliente = 2;
#
# UPDATE Clientes SET nome_cliente = 'Pedro Oliveira', email_cliente = 'pedro.oliveira@example.com', endereco = 'Rua C, 789' WHERE id_cliente = 3;
#
# UPDATE Clientes SET nome_cliente = 'Ana Pereira', email_cliente = 'ana.pereira@example.com', endereco = 'Av. D, 1010' WHERE id_cliente = 4;
#
# UPDATE Clientes SET nome_cliente = 'José Alves', email_cliente = 'jose.alves@example.com', endereco = 'Rua E, 1112' WHERE id_cliente = 5;
#
# UPDATE Clientes SET nome_cliente = 'Mariana Costa', email_cliente = 'mariana.costa@example.com', endereco = 'Av. F, 1314' WHERE id_cliente = 6;
#
# UPDATE Clientes SET nome_cliente = 'Carlos Rodrigues', email_cliente = 'carlos.rodrigues@example.com', endereco = 'Rua G, 1516' WHERE id_cliente = 7;
#
# UPDATE Clientes SET nome_cliente = 'Juliana Fernandes', email_cliente = 'juliana.fernandes@example.com', endereco = 'Av. H, 1718' WHERE id_cliente = 8;
#
# UPDATE Clientes SET nome_cliente = 'Paulo Lima', email_cliente = 'paulo.lima@example.com', endereco = 'Rua I, 1920' WHERE id_cliente = 9;
#
# UPDATE Clientes SET nome_cliente = 'Fernanda Sousa', email_cliente = 'fernanda.sousa@example.com', endereco = 'Av. J, 2122' WHERE id_cliente = 10;
#
# **-- Atualizando produtos**
#
# UPDATE Produtos SET nome_produto = 'Smartphone', preco_unitario = 1500.00, descricao = 'Descrição do smartphone' WHERE id_produto = 1;
#
# UPDATE Produtos SET nome_produto = 'Camiseta', preco_unitario = 50.00, descricao = 'Descrição da camiseta' WHERE id_produto = 2;
#
# UPDATE Produtos SET nome_produto = 'Sofá', preco_unitario = 1200.00, descricao = 'Descrição do sofá' WHERE id_produto = 3;
#
# UPDATE Produtos SET nome_produto = 'Bola de Futebol', preco_unitario = 80.00, descricao = 'Descrição da bola de futebol' WHERE id_produto = 4;
#
# UPDATE Produtos SET nome_produto = 'Shampoo', preco_unitario = 15.00, descricao = 'Descrição do shampoo' WHERE id_produto = 5;
#
# UPDATE Produtos SET nome_produto = 'Notebook', preco_unitario = 2500.00, descricao = 'Descrição do notebook' WHERE id_produto = 6;
#
# UPDATE Produtos SET nome_produto = 'Calça Jeans', preco_unitario = 100.00, descricao = 'Descrição da calça jeans' WHERE id_produto = 7;
#
# UPDATE Produtos SET nome_produto = 'Mesa de Jantar', preco_unitario = 800.00, descricao = 'Descrição da mesa de jantar' WHERE id_produto = 8;
#
# UPDATE Produtos SET nome_produto = 'Raquete de Tênis', preco_unitario = 150.00, descricao = 'Descrição da raquete de tênis' WHERE id_produto = 9;
#
# UPDATE Produtos SET nome_produto = 'Protetor Solar', preco_unitario = 30.00, descricao = 'Descrição do protetor solar' WHERE id_produto = 10;
#
# **-- Atualizando pedidos**
#
# UPDATE Pedidos SET data_pedido = '2024-03-11', status_pedido = 'Em andamento' WHERE id_pedido = 10;
#
# UPDATE Pedidos SET data_pedido = '2024-03-10', status_pedido = 'Concluído' WHERE id_pedido = 11;
#
# UPDATE Pedidos SET data_pedido = '2024-03-09', status_pedido = 'Em andamento' WHERE id_pedido = 12;
#
# UPDATE Pedidos SET data_pedido = '2024-03-08', status_pedido = 'Concluído' WHERE id_pedido = 13;
#
# UPDATE Pedidos SET data_pedido = '2024-03-07', status_pedido = 'Em andamento' WHERE id_pedido = 14;
#
# UPDATE Pedidos SET data_pedido = '2024-03-06', status_pedido = 'Concluído' WHERE id_pedido = 15;
#
# UPDATE Pedidos SET data_pedido = '2024-03-05', status_pedido = 'Em andamento' WHERE id_pedido = 16;
#
# UPDATE Pedidos SET data_pedido = '2024-03-04', status_pedido = 'Concluído' WHERE id_pedido = 17;
#
# UPDATE Pedidos SET data_pedido = '2024-03-03', status_pedido = 'Em andamento' WHERE id_pedido = 18;
#
# UPDATE Pedidos SET data_pedido = '2024-03-02', status_pedido = 'Concluído' WHERE id_pedido = 19;
#
# UPDATE Pedidos SET data_pedido = '2024-03-01', status_pedido = 'Em andamento' WHERE id_pedido = 20;

# %% [markdown]
# ![teste 4.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 5.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 6.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 7.png](data:image/png;base64,...)

# %% [markdown]
# ![teste 8.png](data:image/png;base64,...)

# %% [markdown]
# **TESTANDO AS QUERIES**

# %% [markdown]
# SELECT * FROM Clientes;

# %% [markdown]
# ![teste 9.png](data:image/png;base64,...)

# %% [markdown]
# SELECT * FROM Produtos;

# %% [markdown]
# ![teste 10.png](data:image/png;base64,...)

# %% [markdown]
# SELECT * FROM Categorias;

# %% [markdown]
# ![teste 11.png](data:image/png;base64,...)

# %% [markdown]
# SELECT * FROM Pedidos;

# %%
SELECT * FROM Pedidos;

# %% [markdown]
# ![teste 12.png](data:image/png;base64,...)

# %% [markdown]
# # **AULA 9 - 17/09/2024**

# %% [markdown]
# Continuamos a leitura do material didático referente a etapa 5.

# %% [markdown]
# Professor recomendou ver o vídeo sobre tipos de join: https://www.youtube.com/watch?v=byCI01_ww_0

# %% [markdown]
# Falamos sobre o Modelo Entidade e Relacionamento

# %% [markdown]
# Falamos sobre Sistema ERP como solução de vendas

# %% [markdown]
# Fizemos a leitura do Teste de Perfomance 3 (TP3)

# %% [markdown]
# **Criar Estrutura:**

# %% [markdown]
# CREATE TABLE Categorias (
#
#     id_categoria INTEGER PRIMARY KEY,
#     nome_categoria TEXT
# );
#
# CREATE TABLE Produtos (
#
#     id_produto INTEGER PRIMARY KEY,
#     nome_produto TEXT,
#     preco_unitario REAL,
#     descricao TEXT,
#     id_categoria INTEGER,
#     FOREIGN KEY (id_categoria) REFERENCES Categorias(id_categoria)
# );
#
# CREATE TABLE Clientes (
#
#     id_cliente INTEGER PRIMARY KEY,
#     nome_cliente TEXT,
#     email_cliente TEXT,
#     endereco TEXT
# );
#
# CREATE TABLE Pedidos (
#
#     id_pedido INTEGER PRIMARY KEY,
#     id_cliente INTEGER,
#     data_pedido DATE,
#     status_pedido TEXT,
#     FOREIGN KEY (id_cliente) REFERENCES Clientes(id_cliente)
# );
#
# CREATE TABLE ItensPedido (
#
#     id_item INTEGER PRIMARY KEY,
#     id_pedido INTEGER,
#     id_produto INTEGER,
#     quantidade INTEGER,
#     FOREIGN KEY (id_pedido) REFERENCES Pedidos(id_pedido),
#     FOREIGN KEY (id_produto) REFERENCES Produtos(id_produto)
# );
#
# **-- Inserindo registros na tabela Categorias**
#
# INSERT INTO Categorias (nome_categoria) VALUES ('Eletrônicos');
# INSERT INTO Categorias (nome_categoria) VALUES ('Moda');
# INSERT INTO Categorias (nome_categoria) VALUES ('Casa e Jardim');
# INSERT INTO Categorias (nome_categoria) VALUES ('Esportes e Lazer');
# INSERT INTO Categorias (nome_categoria) VALUES ('Beleza e Saúde');
#
# **-- Inserindo registros na tabela Produtos**
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 1', 10.00, 'Descrição 1', 1);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 2', 20.00, 'Descrição 2', 2);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 3', 30.00, 'Descrição 3', 3);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 4', 40.00, 'Descrição 4', 4);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 5', 50.00, 'Descrição 5', 5);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 6', 60.00, 'Descrição 6', 1);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 7', 70.00, 'Descrição 7', 2);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 8', 80.00, 'Descrição 8', 3);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 9', 90.00, 'Descrição 9', 4);
#
# INSERT INTO Produtos (nome_produto, preco_unitario, descricao, id_categoria) VALUES ('Produto 10', 100.00, 'Descrição 10', 5);
#
#
# **-- Inserindo registros na tabela Clientes**
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 1', 'cliente1@example.com', 'Endereço 1');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 2', 'cliente2@example.com', 'Endereço 2');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 3', 'cliente3@example.com', 'Endereço 3');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 4', 'cliente4@example.com', 'Endereço 4');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 5', 'cliente5@example.com', 'Endereço 5');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 6', 'cliente6@example.com', 'Endereço 6');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 7', 'cliente7@example.com', 'Endereço 7');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 8', 'cliente8@example.com', 'Endereço 8');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 9', 'cliente9@example.com', 'Endereço 9');
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 10', 'cliente10@example.com', 'Endereço 10');
#
# **-- Inserindo registros na tabela Pedidos**
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (1, 1, '2024-03-19', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (2, 2, '2024-03-18', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (3, 3, '2024-03-17', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (4, 4, '2024-03-16', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (5, 5, '2024-03-15', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (6, 6, '2024-03-14', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (7, 7, '2024-03-13', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (8, 8, '2024-03-12', 'Concluído');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (9, 9, '2024-03-11', 'Em andamento');
#
# INSERT INTO Pedidos (id_pedido, id_cliente, data_pedido, status_pedido) VALUES (10, 10, '2024-03-10', 'Concluído');
#
#
# **-- Inserindo registros na tabela ItensPedido**
#
# **-- Pedido 1**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (1, 5, 1);
#
#
# **-- Pedido 2**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 6, 2);
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 7, 1);
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 8, 2);
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 9, 1);
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (2, 10, 3);
#
# **-- Pedido 3**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (3, 5, 1);
#
# **-- Pedido 4**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 6, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 7, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 8, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 9, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (4, 10, 3);
#
# **-- Pedido 5**
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 1, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 2, 2);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 3, 1);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 4, 3);
#
# INSERT INTO ItensPedido (id_pedido, id_produto, quantidade) VALUES (5, 5, 1);
#
# **-- Atualizando clientes**
#
# UPDATE Clientes SET nome_cliente = 'João Silva', email_cliente = 'joao.silva@example.com', endereco = 'Rua A, 123' WHERE id_cliente = 1;
#
# UPDATE Clientes SET nome_cliente = 'Maria Santos', email_cliente = 'maria.santos@example.com', endereco = 'Av. B, 456' WHERE id_cliente = 2;
#
# UPDATE Clientes SET nome_cliente = 'Pedro Oliveira', email_cliente = 'pedro.oliveira@example.com', endereco = 'Rua C, 789' WHERE id_cliente = 3;
#
# UPDATE Clientes SET nome_cliente = 'Ana Pereira', email_cliente = 'ana.pereira@example.com', endereco = 'Av. D, 1010' WHERE id_cliente = 4;
#
# UPDATE Clientes SET nome_cliente = 'José Alves', email_cliente = 'jose.alves@example.com', endereco = 'Rua E, 1112' WHERE id_cliente = 5;
#
# UPDATE Clientes SET nome_cliente = 'Mariana Costa', email_cliente = 'mariana.costa@example.com', endereco = 'Av. F, 1314' WHERE id_cliente = 6;
#
# UPDATE Clientes SET nome_cliente = 'Carlos Rodrigues', email_cliente = 'carlos.rodrigues@example.com', endereco = 'Rua G, 1516' WHERE id_cliente = 7;
#
# UPDATE Clientes SET nome_cliente = 'Juliana Fernandes', email_cliente = 'juliana.fernandes@example.com', endereco = 'Av. H, 1718' WHERE id_cliente = 8;
#
# UPDATE Clientes SET nome_cliente = 'Paulo Lima', email_cliente = 'paulo.lima@example.com', endereco = 'Rua I, 1920' WHERE id_cliente = 9;
#
# UPDATE Clientes SET nome_cliente = 'Fernanda Sousa', email_cliente = 'fernanda.sousa@example.com', endereco = 'Av. J, 2122' WHERE id_cliente = 10;
#
# **-- Atualizando produtos**
#
# UPDATE Produtos SET nome_produto = 'Smartphone', preco_unitario = 1500.00, descricao = 'Descrição do smartphone' WHERE id_produto = 1;
#
# UPDATE Produtos SET nome_produto = 'Camiseta', preco_unitario = 50.00, descricao = 'Descrição da camiseta' WHERE id_produto = 2;
#
# UPDATE Produtos SET nome_produto = 'Sofá', preco_unitario = 1200.00, descricao = 'Descrição do sofá' WHERE id_produto = 3;
#
# UPDATE Produtos SET nome_produto = 'Bola de Futebol', preco_unitario = 80.00, descricao = 'Descrição da bola de futebol' WHERE id_produto = 4;
#
# UPDATE Produtos SET nome_produto = 'Shampoo', preco_unitario = 15.00, descricao = 'Descrição do shampoo' WHERE id_produto = 5;
#
# UPDATE Produtos SET nome_produto = 'Notebook', preco_unitario = 2500.00, descricao = 'Descrição do notebook' WHERE id_produto = 6;
#
# UPDATE Produtos SET nome_produto = 'Calça Jeans', preco_unitario = 100.00, descricao = 'Descrição da calça jeans' WHERE id_produto = 7;
#
# UPDATE Produtos SET nome_produto = 'Mesa de Jantar', preco_unitario = 800.00, descricao = 'Descrição da mesa de jantar' WHERE id_produto = 8;
#
# UPDATE Produtos SET nome_produto = 'Raquete de Tênis', preco_unitario = 150.00, descricao = 'Descrição da raquete de tênis' WHERE id_produto = 9;
#
# UPDATE Produtos SET nome_produto = 'Protetor Solar', preco_unitario = 30.00, descricao = 'Descrição do protetor solar' WHERE id_produto = 10;
#
# **-- Atualizando pedidos**
#
# UPDATE Pedidos SET data_pedido = '2024-03-11', status_pedido = 'Em andamento' WHERE id_pedido = 10;
#
# UPDATE Pedidos SET data_pedido = '2024-03-10', status_pedido = 'Concluído' WHERE id_pedido = 11;
#
# UPDATE Pedidos SET data_pedido = '2024-03-09', status_pedido = 'Em andamento' WHERE id_pedido = 12;
#
# UPDATE Pedidos SET data_pedido = '2024-03-08', status_pedido = 'Concluído' WHERE id_pedido = 13;
#
# UPDATE Pedidos SET data_pedido = '2024-03-07', status_pedido = 'Em andamento' WHERE id_pedido = 14;
#
# UPDATE Pedidos SET data_pedido = '2024-03-06', status_pedido = 'Concluído' WHERE id_pedido = 15;
#
# UPDATE Pedidos SET data_pedido = '2024-03-05', status_pedido = 'Em andamento' WHERE id_pedido = 16;
#
# UPDATE Pedidos SET data_pedido = '2024-03-04', status_pedido = 'Concluído' WHERE id_pedido = 17;
#
# UPDATE Pedidos SET data_pedido = '2024-03-03', status_pedido = 'Em andamento' WHERE id_pedido = 18;
#
# UPDATE Pedidos SET data_pedido = '2024-03-02', status_pedido = 'Concluído' WHERE id_pedido = 19;
#
# UPDATE Pedidos SET data_pedido = '2024-03-01', status_pedido = 'Em andamento' WHERE id_pedido = 20;
#
# **-- Consultas**
#
# select('');
#
# select('Produtos');
#
# select * from produtos;
#
# select('');
#
# select('Categorias');
#
# select * from categorias;
#
# select('');
#
# select('Pedidos');
#
# select * from pedidos;
#
# select('');
#
# select('Clientes');
#
# select * from clientes;
#
# select('');
#
# select('Itens Pedido');
#
# select * from itenspedido;
#
# select('');

# %% [markdown]
# **Atualizar o e-mail do João para um e-mail novo:**

# %% [markdown]
# UPDATE Clientes
#
# SET e-mail_cliente = 'joao.silva_novo@example.com'
#
# WHERE nome_cliente = 'João Silva';

# %% [markdown]
# **Atualizar o preço de todos os produtos da categoria "Moda" com 10%:**

# %% [markdown]
# UPDATE Produtos
#
# SET preco_unitario = preco_unitario * 1.1
#
# WHERE id_categoria = (SELECT id_categoria FROM Categorias WHERE
# nome_categoria = 'Moda');

# %% [markdown]
# **Questão de Concurso:**
#
# **Ano: 2014 Banca: FCC Órgão TRF - 3° REGIÃO Prova: Técnico Judiciário - Informática**
#
# O comando SQL utilizado para inserir a segunda linha apresentada na tabela é:

# %% [markdown]
# 1) ALTER TABLE Cadastro SET LINE 2 = 'Idade';
#
# 2) UPDATE TABLE Cadastro SET Nome = 'Antônio Silva', Idade = 36 WHERE ROW = 2;
#
# 3) INSERT INTO Cadastro VALUE (2, 'Antônio Silva', 36);
#
# 4) INSERT INTO Cadastro VALUES('Antônio Silva', 36) WHERE id = 2;
#
# 5) UPDATE TABLE Cadastro INSERT (2, 'Antônio Silva',36);
#
#
# **A RESPOSTA CORRETA É :**
#
#
# 3) INSERT INTO Cadastro VALUE (2, 'Antônio Silva', 36);

# %% [markdown]
# **Questão de Concurso:**
#
# **Ano: 2013 Banca: ESPP Órgão: COBRA Tecnologia S/A (BB) - Analista de Operações - Administrador de Banco de Dados**
#
# Em SQL se um empregado for promovido a gerente devemos alterar o cargo (CARGO) do empregado número (NUM_EMP) '48729' na tabela EMPREGADOS para o valor GERENTE, usando a seguinte query:

# %% [markdown]
# 1) UPDATE GERENTE WHERE NUM_EMP = '48729';
#
# 2) UPDATE CARGO = GERENTE WHERE NUM_EMP = '48729';
#
# 3) UPDATE EMPREGADOS SET CARGO = GERENTE WHERE NUM_EMP = '48729';
#
# 4) UPDATE EMPREGADOS SET NUM_EMP = '48729';
#
# **A RESPOSTA CORRETA É:**
#
# 3) UPDATE EMPREGADOS SET CARGO = GERENTE WHERE NUM_EMP = '48729';

# %% [markdown]
# **Listas todos os clientes que não fizeram pedido:**

# %% [markdown]
# SELEC * FROM Clientes
# WHERE id_cliente NOT IN (SELECT DISTINCT id_cliente FROM Pedidos);

# %% [markdown]
# --Inserindo um novo cliente
#
# INSERT INTO Clientes (nome_cliente, email_cliente, endereco) VALUES ('Cliente 11', 'cliente11@example.com', 'Endereço 11');
#
# --Listar todos os clientes que não fizeram pedido:
#
# SELECT *
# FROM Clientes
# WHERE id_cliente NOT IN (SELECT DISTINCT id_cliente FROM Pedidos);

# %% [markdown]
# # **AULA 10 - 24/09/2024**

# %% [markdown]
# UPDATE SEM WHERE: https://www.youtube.com/watch?v=2TkGI-SaDXQ

# %% [markdown]
# # **AULA 11 - 01/10/2024**

# %% [markdown]
# # **AULA 12 - 08/10/2024**
